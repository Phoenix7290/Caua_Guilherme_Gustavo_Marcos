# %% [markdown]
# ## Importação de Bibliotecas e Carregamento dos Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/customer_support_tickets.csv")

def print_formatado(*args, prefixo=5, largura_total=100):
    titulo = " ".join(str(a) for a in args)
    print("\n")
    print("=" * 100)
    print(titulo)
    print("=" * 100)

# %% [markdown]
# ## Inspeção Inicial

# %%
print_formatado("1. Tamanho do dataset:")
print(df.shape)

print_formatado("2. Variáveis do dataset:")
print(df.columns)

print_formatado("3. Significado das colunas:")
print("Ver Markdown")

print_formatado("4. Tipos dos dados:")
print(df.dtypes)

print_formatado("5. Organização Registros:")
df.info()
print("Ver Markdown")

print_formatado("6. Exemplo de valores:")
print("\nPrimeiros registros:")
print(df.head())

print("\nÚltimos registros:")
print(df.tail())

print("\nRegistros aleatórios:")
print(df.sample(5, random_state=1))

print("\nExemplo dataset:")
display(df)


print_formatado("7. Identificação das variáveis")
print("\nVariáveis numéricas:")
print(f"Ticket ID: min={df['Ticket ID'].min()}, max={df['Ticket ID'].max()}, média={df['Ticket ID'].mean():.2f}")
print(f"Customer Age: min={df['Customer Age'].min()}, max={df['Customer Age'].max()}, média={df['Customer Age'].mean():.2f}")
print(f"Customer Satisfaction Rating: min={df['Customer Satisfaction Rating'].min()}, max={df['Customer Satisfaction Rating'].max()}, média={df['Customer Satisfaction Rating'].mean():.2f}")

print("\nVariáveis categóricas:")
print(f"Customer Gender: {df['Customer Gender'].unique().tolist()}")
print(f"Product Purchased: {df['Product Purchased'].unique().tolist()}")
print(f"Ticket Type: {df['Ticket Type'].unique().tolist()}")
print(f"Ticket Subject: {df['Ticket Subject'].unique().tolist()}")
print(f"Ticket Status: {df['Ticket Status'].unique().tolist()}")
print(f"Ticket Priority: {df['Ticket Priority'].unique().tolist()}")
print(f"Ticket Channel: {df['Ticket Channel'].unique().tolist()}")

print("\nVariáveis textuais/identificadoras:")
print("Ver Markdown")

print("\nVariáveis de data/hora:")
print("Ver Markdown")
# Out:
# ====================================================================================================
# 1. Tamanho do dataset:
# ====================================================================================================
# (8469, 17)
#
#
# ====================================================================================================
# 2. Variáveis do dataset:
# ====================================================================================================
# Index(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
#        'Customer Gender', 'Product Purchased', 'Date of Purchase',
#        'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
#        'Resolution', 'Ticket Priority', 'Ticket Channel',
#        'First Response Time', 'Time to Resolution',
#        'Customer Satisfaction Rating'],
#       dtype='str')
#
#
# ====================================================================================================
# 3. Significado das colunas:
# ====================================================================================================
# Ver Markdown
#
#
# ====================================================================================================
# 4. Tipos dos dados:
# ====================================================================================================
# Ticket ID                         int64
# Customer Name                       str
# Customer Email                      str
# Customer Age                      int64
# Customer Gender                     str
# Product Purchased                   str
# Date of Purchase                    str
# Ticket Type                         str
# Ticket Subject                      str
# Ticket Description                  str
# Ticket Status                       str
# Resolution                          str
# Ticket Priority                     str
# Ticket Channel                      str
# First Response Time                 str
# Time to Resolution                  str
# Customer Satisfaction Rating    float64
# dtype: object
#
#
# ====================================================================================================
# 5. Organização Registros:
# ====================================================================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ticket ID                     8469 non-null   int64
#  1   Customer Name                 8469 non-null   str
#  2   Customer Email                8469 non-null   str
#  3   Customer Age                  8469 non-null   int64
#  4   Customer Gender               8469 non-null   str
#  5   Product Purchased             8469 non-null   str
#  6   Date of Purchase              8469 non-null   str
#  7   Ticket Type                   8469 non-null   str
#  8   Ticket Subject                8469 non-null   str
#  9   Ticket Description            8469 non-null   str
#  10  Ticket Status                 8469 non-null   str
#  11  Resolution                    2769 non-null   str
#  12  Ticket Priority               8469 non-null   str
#  13  Ticket Channel                8469 non-null   str
#  14  First Response Time           5650 non-null   str
#  15  Time to Resolution            2769 non-null   str
#  16  Customer Satisfaction Rating  2769 non-null   float64
# dtypes: float64(1), int64(2), str(14)
# memory usage: 1.1 MB
# Ver Markdown
#
#
# ====================================================================================================
# 6. Exemplo de valores:
# ====================================================================================================
#
# Primeiros registros:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  \
# 0  I'm having an issue with the {product_purchase...
# 1  I'm having an issue with the {product_purchase...
# 2  I'm facing a problem with my {product_purchase...
# 3  I'm having an issue with the {product_purchase...
# 4  I'm having an issue with the {product_purchase...
#
#                Ticket Status                                     Resolution  \
# 0  Pending Customer Response                                            NaN
# 1  Pending Customer Response                                            NaN
# 2                     Closed   Case maybe show recently my computer follow.
# 3                     Closed  Try capital clearly never color toward story.
# 4                     Closed                    West decision evidence bit.
#
#   Ticket Priority Ticket Channel  First Response Time   Time to Resolution  \
# 0        Critical   Social media  2023-06-01 12:15:36                  NaN
# 1        Critical           Chat  2023-06-01 16:45:38                  NaN
# 2             Low   Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3             Low   Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Low          Email  2023-06-01 00:12:42  2023-06-01 19:53:42
#
#    Customer Satisfaction Rating
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0
#
# Últimos registros:
#       Ticket ID     Customer Name         Customer Email  Customer Age  \
# 8464       8465        David Todd     adam28@example.net            22
# 8465       8466        Lori Davis  russell68@example.com            27
# 8466       8467   Michelle Kelley   ashley83@example.org            57
# 8467       8468  Steven Rodriguez    fpowell@example.org            54
# 8468       8469   Steven Davis MD     lori20@example.net            53
#
#      Customer Gender       Product Purchased Date of Purchase  \
# 8464          Female                 LG OLED       2021-12-08
# 8465          Female  Bose SoundLink Speaker       2020-02-22
# 8466          Female     GoPro Action Camera       2021-08-17
# 8467            Male             PlayStation       2021-10-16
# 8468           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type        Ticket Subject  \
# 8464  Product inquiry  Installation support
# 8465  Technical issue        Refund request
# 8466  Technical issue        Account access
# 8467  Product inquiry         Payment issue
# 8468  Billing inquiry        Hardware issue
#
#                                      Ticket Description Ticket Status  \
# 8464  My {product_purchased} is making strange noise...          Open
# 8465  I'm having an issue with the {product_purchase...          Open
# 8466  I'm having an issue with the {product_purchase...        Closed
# 8467  I'm having an issue with the {product_purchase...        Closed
# 8468  There seems to be a hardware problem with my {...          Open
#
#                                  Resolution Ticket Priority Ticket Channel  \
# 8464                                    NaN             Low          Phone
# 8465                                    NaN        Critical          Email
# 8466  Eight account century nature kitchen.            High   Social media
# 8467                  We seat culture plan.          Medium          Email
# 8468                                    NaN            High          Phone
#
#       First Response Time   Time to Resolution  Customer Satisfaction Rating
# 8464                  NaN                  NaN                           NaN
# 8465                  NaN                  NaN                           NaN
# 8466  2023-06-01 09:44:22  2023-06-01 04:31:22                           3.0
# 8467  2023-06-01 18:28:24  2023-06-01 05:32:24                           3.0
# 8468                  NaN                  NaN                           NaN
#
# Registros aleatórios:
#       Ticket ID      Customer Name          Customer Email  Customer Age  \
# 1825       1826    Angela Humphrey    joshua84@example.com            55
# 473         474      James Escobar  huertaryan@example.com            32
# 3509       3510  Daniel Mccullough    davidcox@example.com            61
# 5415       5416      Nicole Knight    johnhess@example.com            46
# 5537       5538      Jessica Chase   wschwartz@example.com            45
#
#      Customer Gender       Product Purchased Date of Purchase  \
# 1825          Female  Bose SoundLink Speaker       2021-06-11
# 473             Male         Adobe Photoshop       2021-10-08
# 3509            Male         Adobe Photoshop       2021-02-16
# 5415          Female       Bose QuietComfort       2020-08-20
# 5537          Female          Samsung Galaxy       2021-02-02
#
#           Ticket Type          Ticket Subject  \
# 1825  Billing inquiry          Hardware issue
# 473   Technical issue          Hardware issue
# 3509   Refund request  Product recommendation
# 5415   Refund request            Software bug
# 5537  Technical issue            Software bug
#
#                                      Ticket Description  \
# 1825  I'm having an issue with the {product_purchase...
# 473   I'm having an issue with the {product_purchase...
# 3509  I'm encountering a software bug in the {produc...
# 5415  I'm having an issue with the {product_purchase...
# 5537  I'm having an issue with the {product_purchase...
#
#                   Ticket Status  \
# 1825                     Closed
# 473                        Open
# 3509                       Open
# 5415  Pending Customer Response
# 5537                     Closed
#
#                                              Resolution Ticket Priority  \
# 1825                       Any because size far record.            High
# 473                                                 NaN          Medium
# 3509                                                NaN        Critical
# 5415                                                NaN            High
# 5537  Debate wife window kitchen inside tonight give...             Low
#
#      Ticket Channel  First Response Time   Time to Resolution  \
# 1825           Chat  2023-06-01 17:06:29  2023-06-01 06:25:29
# 473           Phone                  NaN                  NaN
# 3509           Chat                  NaN                  NaN
# 5415           Chat  2023-06-01 13:49:59                  NaN
# 5537          Phone  2023-05-31 23:53:47  2023-06-01 13:18:47
#
#       Customer Satisfaction Rating
# 1825                           2.0
# 473                            NaN
# 3509                           NaN
# 5415                           NaN
# 5537                           2.0
#
# Exemplo dataset:
#       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       2021-03-22
# 1               42          Female             LG Smart TV       2021-05-22
# 2               48           Other                Dell XPS       2020-07-14
# 3               27          Female        Microsoft Office       2020-11-13
# 4               67          Female        Autodesk AutoCAD       2020-02-04
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       2021-12-08
# 8465            27          Female  Bose SoundLink Speaker       2020-02-22
# 8466            57          Female     GoPro Action Camera       2021-08-17
# 8467            54            Male             PlayStation       2021-10-16
# 8468            53           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status  \
# 0     Pending Customer Response
# 1     Pending Customer Response
# 2                        Closed
# 3                        Closed
# 4                        Closed
# ...                         ...
# 8464                       Open
# 8465                       Open
# 8466                     Closed
# 8467                     Closed
# 8468                       Open
#
#                                          Resolution Ticket Priority  \
# 0                                               NaN        Critical
# 1                                               NaN        Critical
# 2      Case maybe show recently my computer follow.             Low
# 3     Try capital clearly never color toward story.             Low
# 4                       West decision evidence bit.             Low
# ...                                             ...             ...
# 8464                                            NaN             Low
# 8465                                            NaN        Critical
# 8466          Eight account century nature kitchen.            High
# 8467                          We seat culture plan.          Medium
# 8468                                            NaN            High
#
#      Ticket Channel  First Response Time   Time to Resolution  \
# 0      Social media  2023-06-01 12:15:36                  NaN
# 1              Chat  2023-06-01 16:45:38                  NaN
# 2      Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3      Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Email  2023-06-01 00:12:42  2023-06-01 19:53:42
# ...             ...                  ...                  ...
# 8464          Phone                  NaN                  NaN
# 8465          Email                  NaN                  NaN
# 8466   Social media  2023-06-01 09:44:22  2023-06-01 04:31:22
# 8467          Email  2023-06-01 18:28:24  2023-06-01 05:32:24
# 8468          Phone                  NaN                  NaN
#
#       Customer Satisfaction Rating
# 0                              NaN
# 1                              NaN
# 2                              3.0
# 3                              3.0
# 4                              1.0
# ...                            ...
# 8464                           NaN
# 8465                           NaN
# 8466                           3.0
# 8467                           3.0
# 8468                           NaN
#
# [8469 rows x 17 columns]
# ====================================================================================================
# 7. Identificação das variáveis
# ====================================================================================================
#
# Variáveis numéricas:
# Ticket ID: min=1, max=8469, média=4235.00
# Customer Age: min=18, max=70, média=44.03
# Customer Satisfaction Rating: min=1.0, max=5.0, média=2.99
#
# Variáveis categóricas:
# Customer Gender: ['Other', 'Female', 'Male']
# Product Purchased: ['GoPro Hero', 'LG Smart TV', 'Dell XPS', 'Microsoft Office', 'Autodesk AutoCAD', 'Microsoft Surface', 'Philips Hue Lights', 'Fitbit Versa Smartwatch', 'Dyson Vacuum Cleaner', 'Nintendo Switch', 'Microsoft Xbox Controller', 'Nintendo Switch Pro Controller', 'Nest Thermostat', 'Sony PlayStation', 'GoPro Action Camera', 'Xbox', 'LG Washing Machine', 'Canon EOS', 'HP Pavilion', 'Amazon Kindle', 'Lenovo ThinkPad', 'Fitbit Charge', 'Adobe Photoshop', 'Google Pixel', 'Amazon Echo', 'PlayStation', 'Samsung Galaxy', 'iPhone', 'LG OLED', 'Sony Xperia', 'Apple AirPods', 'Sony 4K HDR TV', 'Canon DSLR Camera', 'Roomba Robot Vacuum', 'Nikon D', 'Bose QuietComfort', 'Samsung Soundbar', 'Asus ROG', 'Bose SoundLink Speaker', 'Google Nest', 'Garmin Forerunner', 'MacBook Pro']
# Ticket Type: ['Technical issue', 'Billing inquiry', 'Cancellation request', 'Product inquiry', 'Refund request']
# Ticket Subject: ['Product setup', 'Peripheral compatibility', 'Network problem', 'Account access', 'Data loss', 'Payment issue', 'Refund request', 'Battery life', 'Installation support', 'Software bug', 'Hardware issue', 'Product recommendation', 'Delivery problem', 'Display issue', 'Cancellation request', 'Product compatibility']
# Ticket Status: ['Pending Customer Response', 'Closed', 'Open']
# Ticket Priority: ['Critical', 'Low', 'High', 'Medium']
# Ticket Channel: ['Social media', 'Chat', 'Email', 'Phone']
#
# Variáveis textuais/identificadoras:
# Ver Markdown
#
# Variáveis de data/hora:
# Ver Markdown

# %% [markdown]
# ### Análise da Inspeção Inicial
#
# **3. Significado das colunas**
#
# | Coluna | Descrição |
# |---|---|
# | `Ticket ID` | Identificador único e sequencial do chamado. |
# | `Customer Name` | Nome do cliente que abriu o chamado. |
# | `Customer Email` | E-mail do cliente (dado de contato/PII). |
# | `Customer Age` | Idade do cliente em anos. |
# | `Customer Gender` | Gênero informado pelo cliente (`Male`, `Female`, `Other`). |
# | `Product Purchased` | Produto ao qual o chamado se refere (42 produtos distintos). |
# | `Date of Purchase` | Data em que o produto foi comprado. |
# | `Ticket Type` | Categoria do chamado (ex.: `Technical issue`, `Billing inquiry`). |
# | `Ticket Subject` | Assunto específico dentro do tipo de chamado (16 assuntos). |
# | `Ticket Description` | Texto livre descrevendo o problema relatado pelo cliente. |
# | `Ticket Status` | Situação atual do chamado (`Open`, `Pending Customer Response`, `Closed`). |
# | `Resolution` | Texto livre com a solução aplicada — só existe para chamados `Closed`. |
# | `Ticket Priority` | Prioridade atribuída ao chamado (`Low`, `Medium`, `High`, `Critical`). |
# | `Ticket Channel` | Canal de abertura do chamado (`Email`, `Phone`, `Chat`, `Social media`). |
# | `First Response Time` | Data/hora da primeira resposta da equipe de suporte. |
# | `Time to Resolution` | Data/hora em que o chamado foi resolvido — só existe para `Closed`. |
# | `Customer Satisfaction Rating` | Nota de satisfação (1 a 5) — só existe para chamados `Closed`. |
#
# **5. Organização dos registros**
#
# Cada linha representa **um chamado de suporte** (grão = ticket), sem hierarquia entre linhas. O `df.info()` mostra 8.469 registros e 17 colunas, majoritariamente do tipo `object` (texto/categoria), com `Ticket ID` e `Customer Age` como `int64` e `Customer Satisfaction Rating` como `float64` (por conter nulos). Os tipos batem com a natureza de cada coluna — nenhuma conversão incoerente aparente nesta etapa.
#
# **Variáveis textuais/identificadoras**
#
# - `Ticket ID`, `Customer Name`, `Customer Email`: identificam o registro/cliente, não devem entrar em estatísticas ou modelos como feature.
# - `Ticket Description`, `Resolution`: texto livre em linguagem natural, candidatos a análise de NLP (não a estatística descritiva tradicional).
#
# **Variáveis de data/hora**
#
# - `Date of Purchase`, `First Response Time`, `Time to Resolution` estão como `object` (string), não como `datetime` — precisam de `pd.to_datetime()` antes de qualquer cálculo de prazo/duração.
# - `First Response Time` e `Time to Resolution` só existem, respectivamente, para chamados que já receberam resposta e para chamados já resolvidos.

# %% [markdown]
# ## Verificação da Qualidade dos Dados

# %%
import unicodedata

colunas_categoricas = ["Customer Gender", "Product Purchased", "Ticket Type", "Ticket Subject", "Ticket Status", "Ticket Priority", "Ticket Channel"]

print_formatado("1. Valores ausentes:")
print("Valores ausentes (NaN):")
print(df.isnull().sum())

print("\nValores ausentes representados por '?':")
for coluna in df.select_dtypes(include="object").columns:
    qtd_interrogacao = (df[coluna].str.strip() == "?").sum()
    print(f"{coluna:<30}: {qtd_interrogacao}")
print("Ver Markdown")

print_formatado("2. Registros duplicados:")
print("Duplicatas completas:")
print(df.duplicated().sum())

print("\nDuplicadas desconsiderando Ticket ID:")
print(df.drop(columns=["Ticket ID"]).duplicated().sum())
print("Ver Markdown")

print_formatado("3. Tipos de Dados:")
for coluna in df:
    print(df[coluna].apply(type).value_counts())

print("\nQuantidade de categorias por coluna:")
for coluna in df:
    print(f"{coluna:<30}: {df[coluna].nunique()}")

print("\nDistribuição absoluta:")
for coluna in df:
    if df[coluna].dtype != "object":
        continue
    print(df[coluna].value_counts(), "\n")
print("Ver Markdown")


print_formatado("4. Categorias escritas de maneira diferente:")
def normalizar_texto(valor):
    if pd.isna(valor):
        return valor

    valor = valor.strip().lower()
    valor = (
        unicodedata.normalize('NFKD', valor)
        .encode('ASCII', 'ignore')
        .decode('utf-8')
    )

    return valor

for coluna in colunas_categoricas:
    com_normalizacao = df[coluna].apply(normalizar_texto).nunique()
    sem_normalizacao = df[coluna].nunique()
    print(f"{coluna:<30} -> Com Normalização: {com_normalizacao} | Sem Normalização: {sem_normalizacao}")

print_formatado("5. Textos vazios ou espaços extras:")
for coluna in colunas_categoricas:
    qtd_espacos = (df[coluna] != df[coluna].str.strip()).sum()
    print(f"{coluna:<30}: {qtd_espacos}")

print_formatado("6. Valores impossíveis ou fora do contexto:")
print("\nValores impossíveis:")
print(f"Customer Age mínimo                  : {df['Customer Age'].min()}")
print(f"Customer Age máximo                  : {df['Customer Age'].max()}")
print(f"Customer Age < 18 ou > 100            : {df['Customer Age'][(df['Customer Age'] < 18) | (df['Customer Age'] > 100)].count()}")
print(f"Customer Satisfaction Rating mínimo   : {df['Customer Satisfaction Rating'].min()}")
print(f"Customer Satisfaction Rating máximo   : {df['Customer Satisfaction Rating'].max()}")
print(f"Rating fora do intervalo 1-5          : {df['Customer Satisfaction Rating'][(df['Customer Satisfaction Rating'] < 1) | (df['Customer Satisfaction Rating'] > 5)].count()}")

print("\nDatas fora de um intervalo plausível:")
data_compra = pd.to_datetime(df["Date of Purchase"], errors="coerce")
resposta = pd.to_datetime(df["First Response Time"], errors="coerce")
resolucao = pd.to_datetime(df["Time to Resolution"], errors="coerce")
print(f"Date of Purchase mínima               : {data_compra.min()}")
print(f"Date of Purchase máxima               : {data_compra.max()}")
print(f"Datas de compra não convertidas       : {data_compra.isna().sum() - df['Date of Purchase'].isna().sum()}")

print("\nConsistência temporal entre as colunas de data/hora:")
print(f"First Response Time antes de Date of Purchase  : {(resposta < data_compra).sum()}")
print(f"Time to Resolution antes de First Response Time: {(resolucao < resposta).sum()}")

print("\nInconsistência de capitalização (mesmo valor, cases diferentes):")
for coluna in colunas_categoricas:
    valores_lower = df[coluna].str.lower()
    qtd_original = df[coluna].nunique()
    qtd_lower = valores_lower.nunique()
    if qtd_original != qtd_lower:
        print(f"{coluna:<30}: {qtd_original} categorias originais -> {qtd_lower} após lowercase")
    else:
        print(f"{coluna:<30}: sem inconsistência de capitalização")

print("\nCaracteres inesperados em colunas categóricas (fora de letras, espaço, hífen e '/'):")
for coluna in colunas_categoricas:
    padrao = r"[^A-Za-zÀ-ú\s\-/]"
    qtd_estranhos = df[coluna][df[coluna].str.contains(padrao, na=False, regex=True)].nunique()
    valores_estranhos = df[coluna][df[coluna].str.contains(padrao, na=False, regex=True)].unique()
    if qtd_estranhos > 0:
        print(f"{coluna:<30}: {qtd_estranhos} valor(es) -> {list(valores_estranhos)}")
    else:
        print(f"{coluna:<30}: nenhum caractere inesperado")

print("\nConsistência entre 'Ticket Status' e presença dos campos de resolução:")
fechados_sem_resolucao = df[(df["Ticket Status"] == "Closed") & (df["Resolution"].isna())].shape[0]
abertos_com_resolucao = df[(df["Ticket Status"] != "Closed") & (df["Resolution"].notna())].shape[0]
print(f"Tickets 'Closed' sem Resolution preenchida       : {fechados_sem_resolucao}")
print(f"Tickets não 'Closed' com Resolution preenchida   : {abertos_com_resolucao}")
# Out:
# ====================================================================================================
# 1. Valores ausentes:
# ====================================================================================================
# Valores ausentes (NaN):
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Resolution                      5700
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating    5700
# dtype: int64
#
# Valores ausentes representados por '?':
# Customer Name                 : 0
# Customer Email                : 0
# Customer Gender               : 0
# Product Purchased             : 0
# Date of Purchase              : 0
# Ticket Type                   : 0
# Ticket Subject                : 0
# Ticket Description            : 0
# Ticket Status                 : 0
# Resolution                    : 0
# Ticket Priority               : 0
# Ticket Channel                : 0
# First Response Time           : 0
# Time to Resolution            : 0
# Ver Markdown
#
#
# ====================================================================================================
# 2. Registros duplicados:
# ====================================================================================================
# Duplicatas completas:
# 0
#
# Duplicadas desconsiderando Ticket ID:
# 0
# Ver Markdown
#
#
# ====================================================================================================
# 3. Tipos de Dados:
# ====================================================================================================
# Ticket ID
# <class 'int'>    8469
# Name: count, dtype: int64
# Customer Name
# <class 'str'>    8469
# Name: count, dtype: int64
# Customer Email
# <class 'str'>    8469
# Name: count, dtype: int64
# Customer Age
# <class 'int'>    8469
# Name: count, dtype: int64
# Customer Gender
# <class 'str'>    8469
# Name: count, dtype: int64
# Product Purchased
# <class 'str'>    8469
# Name: count, dtype: int64
# Date of Purchase
# <class 'str'>    8469
# Name: count, dtype: int64
# Ticket Type
# <class 'str'>    8469
# Name: count, dtype: int64
# Ticket Subject
# <class 'str'>    8469
# Name: count, dtype: int64
# Ticket Description
# <class 'str'>    8469
# Name: count, dtype: int64
# Ticket Status
# <class 'str'>    8469
# Name: count, dtype: int64
# Resolution
# <class 'float'>    5700
# <class 'str'>      2769
# Name: count, dtype: int64
# Ticket Priority
# <class 'str'>    8469
# Name: count, dtype: int64
# Ticket Channel
# <class 'str'>    8469
# Name: count, dtype: int64
# First Response Time
# <class 'str'>      5650
# <class 'float'>    2819
# Name: count, dtype: int64
# Time to Resolution
# <class 'float'>    5700
# <class 'str'>      2769
# Name: count, dtype: int64
# Customer Satisfaction Rating
# <class 'float'>    8469
# Name: count, dtype: int64
#
# Quantidade de categorias por coluna:
# Ticket ID                     : 8469
# Customer Name                 : 8028
# Customer Email                : 8320
# Customer Age                  : 53
# Customer Gender               : 3
# Product Purchased             : 42
# Date of Purchase              : 730
# Ticket Type                   : 5
# Ticket Subject                : 16
# Ticket Description            : 8077
# Ticket Status                 : 3
# Resolution                    : 2769
# Ticket Priority               : 4
# Ticket Channel                : 4
# First Response Time           : 5470
# Time to Resolution            : 2728
# Customer Satisfaction Rating  : 5
#
# Distribuição absoluta:
# Ver Markdown
#
#
# ====================================================================================================
# 4. Categorias escritas de maneira diferente:
# ====================================================================================================
# Customer Gender                -> Com Normalização: 3 | Sem Normalização: 3
# Product Purchased              -> Com Normalização: 42 | Sem Normalização: 42
# Ticket Type                    -> Com Normalização: 5 | Sem Normalização: 5
# Ticket Subject                 -> Com Normalização: 16 | Sem Normalização: 16
# Ticket Status                  -> Com Normalização: 3 | Sem Normalização: 3
# Ticket Priority                -> Com Normalização: 4 | Sem Normalização: 4
# Ticket Channel                 -> Com Normalização: 4 | Sem Normalização: 4
#
#
# ====================================================================================================
# 5. Textos vazios ou espaços extras:
# ====================================================================================================
# Customer Gender               : 0
# Product Purchased             : 0
# Ticket Type                   : 0
# Ticket Subject                : 0
# Ticket Status                 : 0
# Ticket Priority               : 0
# Ticket Channel                : 0
#
#
# ====================================================================================================
# 6. Valores impossíveis ou fora do contexto:
# ====================================================================================================
#
# Valores impossíveis:
# Customer Age mínimo                  : 18
# Customer Age máximo                  : 70
# Customer Age < 18 ou > 100            : 0
# Customer Satisfaction Rating mínimo   : 1.0
# Customer Satisfaction Rating máximo   : 5.0
# Rating fora do intervalo 1-5          : 0
#
# Datas fora de um intervalo plausível:
# Date of Purchase mínima               : 2020-01-01 00:00:00
# Date of Purchase máxima               : 2021-12-30 00:00:00
# Datas de compra não convertidas       : 0
#
# Consistência temporal entre as colunas de data/hora:
# First Response Time antes de Date of Purchase  : 0
# Time to Resolution antes de First Response Time: 1365
#
# Inconsistência de capitalização (mesmo valor, cases diferentes):
# Customer Gender               : sem inconsistência de capitalização
# Product Purchased             : sem inconsistência de capitalização
# Ticket Type                   : sem inconsistência de capitalização
# Ticket Subject                : sem inconsistência de capitalização
# Ticket Status                 : sem inconsistência de capitalização
# Ticket Priority               : sem inconsistência de capitalização
# Ticket Channel                : sem inconsistência de capitalização
#
# Caracteres inesperados em colunas categóricas (fora de letras, espaço, hífen e '/'):
# Customer Gender               : nenhum caractere inesperado
# Product Purchased             : 1 valor(es) -> ['Sony 4K HDR TV']
# Ticket Type                   : nenhum caractere inesperado
# Ticket Subject                : nenhum caractere inesperado
# Ticket Status                 : nenhum caractere inesperado
# Ticket Priority               : nenhum caractere inesperado
# Ticket Channel                : nenhum caractere inesperado
#
# Consistência entre 'Ticket Status' e presença dos campos de resolução:
# Tickets 'Closed' sem Resolution preenchida       : 0
# Tickets não 'Closed' com Resolution preenchida   : 0
# /var/folders/fq/9y4m8nwn2k7csvmj8sgbvgqr0000gn/T/ipykernel_13371/2679508901.py:10: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for coluna in df.select_dtypes(include="object").columns:

# %% [markdown]
# ### Análise da Verificação de Qualidade
#
# **1. Valores ausentes**
#
# Não há valores representados por `'?'` — os nulos aparecem só como `NaN` mesmo, em 4 colunas:
#
# - `Resolution`, `Time to Resolution` e `Customer Satisfaction Rating`: 5.700 nulos cada — exatamente os chamados que **ainda não estão `Closed`**. Não é dado faltante por erro de coleta, é ausência estrutural (esses campos só existem quando o ticket é resolvido).
# - `First Response Time`: 2.819 nulos — chamados que ainda não receberam a primeira resposta da equipe (subconjunto dos que não estão `Closed`).
#
# Ou seja, o percentual de nulos deve ser tratado por segmentação (`Ticket Status`), e não por imputação genérica.
#
# **2. Registros duplicados**
#
# Zero duplicatas completas e zero duplicatas mesmo ignorando `Ticket ID` — não há indício de linhas repetidas a remover.
#
# **3. Tipos de dados e distribuição de categorias**
#
# Os tipos por coluna são consistentes (sem mistura de `int`/`str` na mesma coluna). A quantidade de categorias e a distribuição absoluta mostram um dataset **bem balanceado**, típico de dado sintético/gerado:
#
# - `Ticket Status`: `Pending Customer Response` (2.881), `Open` (2.819), `Closed` (2.769) — praticamente um terço cada.
# - `Ticket Priority`: entre 2.063 (`Low`) e 2.192 (`Medium`) — as 4 categorias bem próximas.
# - `Ticket Channel`: entre 2.073 (`Chat`) e 2.143 (`Email`) — os 4 canais bem próximos.
# - `Customer Gender`: `Male` (2.896), `Female` (2.887), `Other` (2.686) — sem desbalanceamento relevante.
#
# Não há classe rara/dominante em nenhuma coluna categórica, o que reduz a preocupação com desbalanceamento para análises futuras, mas também é um sinal de que a distribuição não reflete necessariamente um cenário real de suporte (que tende a ser mais desbalanceado).

# %% [markdown]
# ## Limpeza dos dados

# %% [markdown]
# ### Script

# %%
print_formatado("1. Remover/tratar registros duplicados desnecessários;")
print("\nRemover duplicadas completas:")

print(f"Duplicatas completas: {df.duplicated().sum()}")
print(f"Duplicadas desconsiderando Ticket ID: {df.drop(columns=['Ticket ID']).duplicated().sum()}")

print("Não há duplicatas para remover")


print_formatado("2. Remover/tratar valores ausentes de forma justificada;")

print("Valores ausentes antes do tratamento:")
nulos = df.isnull().sum()
print(nulos[nulos > 0])

print("\nVerificação da origem dos nulos:")
print(f"{'Tickets não Closed':<40}: {(df['Ticket Status'] != 'Closed').sum()}")
print(f"{'Nulos em Resolution':<40}: {df['Resolution'].isna().sum()}")
print(f"{'Nulos em Time to Resolution':<40}: {df['Time to Resolution'].isna().sum()}")
print(f"{'Nulos em Customer Satisfaction Rating':<40}: {df['Customer Satisfaction Rating'].isna().sum()}")
print(f"{'Tickets Open':<40}: {(df['Ticket Status'] == 'Open').sum()}")
print(f"{'Nulos em First Response Time':<40}: {df['First Response Time'].isna().sum()}")
print("Ver Markdown")


print_formatado("3. Corrigir tipos das colunas:")

colunas_data = ["Date of Purchase", "First Response Time", "Time to Resolution"]
prioridades_ordenadas = ["Low", "Medium", "High", "Critical"]

print("Tipos antes da conversão:")
print(df[colunas_data + ["Customer Satisfaction Rating"] + colunas_categoricas].dtypes)

for coluna in colunas_data:
    df[coluna] = pd.to_datetime(df[coluna], errors="coerce")

df["Customer Satisfaction Rating"] = df["Customer Satisfaction Rating"].astype("Int8")

for coluna in colunas_categoricas:
    if coluna == "Ticket Priority":
        df[coluna] = pd.Categorical(df[coluna], categories=prioridades_ordenadas, ordered=True)
    else:
        df[coluna] = df[coluna].astype("category")

print("\nTipos depois da conversão:")
print(df[colunas_data + ["Customer Satisfaction Rating"] + colunas_categoricas].dtypes)


print_formatado("4. Corrigir espaços, erros de preenchimento e inconsistências evidentes;")

print("Não foi verificado na etapa de qualidade espaços extras para corrigir.")

qtd_placeholder = df["Ticket Description"].str.contains("{product_purchased}", regex=False).sum()
print(f"\nDescrições com o placeholder '{{product_purchased}}' antes : {qtd_placeholder}")

df["Ticket Description"] = [
    descricao.replace("{product_purchased}", produto)
    for descricao, produto in zip(df["Ticket Description"], df["Product Purchased"])
]

qtd_placeholder = df["Ticket Description"].str.contains("{product_purchased}", regex=False).sum()
print(f"Descrições com o placeholder '{{product_purchased}}' depois: {qtd_placeholder}")
print("Ver Markdown")


print_formatado("5. Corrigir valores inválidos;")

invalidos = df["Time to Resolution"] < df["First Response Time"]
print(f"Tickets com Time to Resolution anterior ao First Response Time antes : {invalidos.sum()}")

df.loc[invalidos, "Time to Resolution"] = pd.NaT

print(f"Tickets com Time to Resolution anterior ao First Response Time depois: {(df['Time to Resolution'] < df['First Response Time']).sum()}")
print(f"Tickets 'Closed' com Time to Resolution nulo após o tratamento       : {((df['Ticket Status'] == 'Closed') & (df['Time to Resolution'].isna())).sum()}")
print("Ver Markdown")
# Out:
# ====================================================================================================
# 1. Remover/tratar registros duplicados desnecessários;
# ====================================================================================================
#
# Remover duplicadas completas:
# Duplicatas completas: 0
# Duplicadas desconsiderando Ticket ID: 0
# Não há duplicatas para remover
#
#
# ====================================================================================================
# 2. Remover/tratar valores ausentes de forma justificada;
# ====================================================================================================
# Valores ausentes antes do tratamento:
# Resolution                      5700
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating    5700
# dtype: int64
#
# Verificação da origem dos nulos:
# Tickets não Closed                      : 5700
# Nulos em Resolution                     : 5700
# Nulos em Time to Resolution             : 5700
# Nulos em Customer Satisfaction Rating   : 5700
# Tickets Open                            : 2819
# Nulos em First Response Time            : 2819
# Ver Markdown
#
#
# ====================================================================================================
# 3. Corrigir tipos das colunas:
# ====================================================================================================
# Tipos antes da conversão:
# Date of Purchase                    str
# First Response Time                 str
# Time to Resolution                  str
# Customer Satisfaction Rating    float64
# Customer Gender                     str
# Product Purchased                   str
# Ticket Type                         str
# Ticket Subject                      str
# Ticket Status                       str
# Ticket Priority                     str
# Ticket Channel                      str
# dtype: object
#
# Tipos depois da conversão:
# Date of Purchase                datetime64[us]
# First Response Time             datetime64[us]
# Time to Resolution              datetime64[us]
# Customer Satisfaction Rating              Int8
# Customer Gender                       category
# Product Purchased                     category
# Ticket Type                           category
# Ticket Subject                        category
# Ticket Status                         category
# Ticket Priority                       category
# Ticket Channel                        category
# dtype: object
#
#
# ====================================================================================================
# 4. Corrigir espaços, erros de preenchimento e inconsistências evidentes;
# ====================================================================================================
# Não foi verificado na etapa de qualidade espaços extras para corrigir.
#
# Descrições com o placeholder '{product_purchased}' antes : 8469
# Descrições com o placeholder '{product_purchased}' depois: 0
# Ver Markdown
#
#
# ====================================================================================================
# 5. Corrigir valores inválidos;
# ====================================================================================================
# Tickets com Time to Resolution anterior ao First Response Time antes : 1365
# Tickets com Time to Resolution anterior ao First Response Time depois: 0
# Tickets 'Closed' com Time to Resolution nulo após o tratamento       : 1365
# Ver Markdown

# %% [markdown]
# ### Observações Limpeza dos Dados

# %% [markdown]
# #### 1. Remover/tratar registros duplicados desnecessários
# * Não há duplicatas completas nem duplicatas desconsiderando `Ticket ID`.
#     * Nenhuma remoção necessária.
#
# #### 2. Remover/tratar valores ausentes de forma justificada
# * Os nulos são estruturais: `Resolution`, `Time to Resolution` e `Customer Satisfaction Rating` (5.700) correspondem exatamente aos tickets não `Closed`; `First Response Time` (2.819) aos tickets `Open`.
#     * Manter os `NaN`: imputar criaria dados que não existem e remover as linhas descartaria ~67% do dataset.
#         * Análises desses campos devem filtrar por `Ticket Status` (ex.: satisfação média apenas entre `Closed`).
#
# #### 3. Corrigir tipos das colunas
# * Converter `Date of Purchase`, `First Response Time` e `Time to Resolution` de `object` para `datetime64`.
# * Converter `Customer Satisfaction Rating` de `float64` para `Int8`: a nota é discreta de 1 a 5, só era float por causa dos nulos.
# * Converter as colunas categóricas para o tipo `category`, com `Ticket Priority` ordenada (`Low < Medium < High < Critical`).
#
# #### 4. Corrigir espaços, erros de preenchimento e inconsistências evidentes
# * Todas as 8.469 descrições de `Ticket Description` contêm o placeholder `{product_purchased}` sem substituição.
#     * Substituir o placeholder pelo valor de `Product Purchased` da própria linha.
#
# #### 5. Corrigir valores inválidos
# * 1.365 tickets com `Time to Resolution` anterior ao `First Response Time` (resolução antes da primeira resposta).
#     * Converter o `Time to Resolution` desses registros para `NaT`, pois não há como recuperar o valor real.
#         * Esses tickets são `Closed` e ficam sem data de resolução; cálculos de duração passam a usar apenas o subconjunto com timestamp válido.
#
# #### Outras observações:
# * Não há espaços extras, diferenças de capitalização ou acentuação a corrigir nas colunas categóricas.
# * Não há valores fora de faixa em `Customer Age` (18 a 70) nem em `Customer Satisfaction Rating` (1 a 5).
# * As datas de compra estão em intervalo plausível (2020-01-01 a 2021-12-30) e nenhuma falhou na conversão.

# %% [markdown]
# ## Análise Univariada

# %% [markdown]
# ### Variáveis númericas

# %%
colunas_numericas = ["Customer Age", "Customer Satisfaction Rating"]


print_formatado("1. Média, mediana, mínimo e máximo:")
for coluna in colunas_numericas:
    print(f"\nVariável '{coluna}':")
    print(f"Média: {df[coluna].mean():.2f}")
    print(f"Mediana: {df[coluna].median():.2f}")
    print(f"Mínimo: {df[coluna].min()}")
    print(f"Máximo: {df[coluna].max()}")


print_formatado("2. Quartis, variância e desvio-padrão:")
for coluna in colunas_numericas:
    q1 = df[coluna].quantile(0.25)
    q2 = df[coluna].quantile(0.50)
    q3 = df[coluna].quantile(0.75)

    print(f"\nVariável '{coluna}':")
    print(f"Q1 (25%): {q1:.2f}")
    print(f"Q2 (50% - mediana): {q2:.2f}")
    print(f"Q3 (75%): {q3:.2f}")
    print(f"Variância: {df[coluna].var():.2f}")
    print(f"Desvio-padrão: {df[coluna].std():.2f}")

print_formatado("3. Distribuição dos valores:")
for coluna in colunas_numericas:
    print(f"\nVariável '{coluna}':")
    print(df[coluna].describe())

    plt.figure(figsize=(10, 4))
    if df[coluna].nunique() <= 10:
        sns.histplot(df[coluna].dropna(), discrete=True, shrink=0.8)
    else:
        sns.histplot(df[coluna], kde=True, bins=30)
    plt.title(f"Distribuição de '{coluna}'")
    plt.xlabel(coluna)
    plt.ylabel("Frequência")
    plt.tight_layout()
    plt.show()
# Out:
# ====================================================================================================
# 1. Média, mediana, mínimo e máximo:
# ====================================================================================================
#
# Variável 'Customer Age':
# Média: 44.03
# Mediana: 44.00
# Mínimo: 18
# Máximo: 70
#
# Variável 'Customer Satisfaction Rating':
# Média: 2.99
# Mediana: 3.00
# Mínimo: 1
# Máximo: 5
#
#
# ====================================================================================================
# 2. Quartis, variância e desvio-padrão:
# ====================================================================================================
#
# Variável 'Customer Age':
# Q1 (25%): 31.00
# Q2 (50% - mediana): 44.00
# Q3 (75%): 57.00
# Variância: 233.97
# Desvio-padrão: 15.30
#
# Variável 'Customer Satisfaction Rating':
# Q1 (25%): 2.00
# Q2 (50% - mediana): 3.00
# Q3 (75%): 4.00
# Variância: 1.98
# Desvio-padrão: 1.41
#
#
# ====================================================================================================
# 3. Distribuição dos valores:
# ====================================================================================================
#
# Variável 'Customer Age':
# count    8469.000000
# mean       44.026804
# std        15.296112
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Customer Age, dtype: float64
# Variável 'Customer Satisfaction Rating':
# count      2769.0
# mean     2.991333
# std      1.407016
# min           1.0
# 25%           2.0
# 50%           3.0
# 75%           4.0
# max           5.0
# Name: Customer Satisfaction Rating, dtype: Float64

# %% [markdown]
# ### Variáveis categóricas

# %%
colunas_categoricas = ["Customer Gender", "Product Purchased", "Ticket Type", "Ticket Subject", "Ticket Status", "Ticket Priority", "Ticket Channel"]

nivel_desequilibrio = 2

print("1. Quantidade de categorias:")
print("\nQuantidade de categorias únicas por variável:")
quantidade_categorias = df[colunas_categoricas].nunique()
print(quantidade_categorias)


print_formatado("2. Frequência absoluta e relativa:")

print("\nFrequência absoluta:")
for coluna in colunas_categoricas:
    frequencia_absoluta = df[coluna].value_counts(dropna=False)
    print(f"\nVariável '{coluna}':")
    print(frequencia_absoluta)

    plt.figure(figsize=(10, 5))

    frequencia_absoluta.plot(kind="bar")

    plt.title(f"Frequência absoluta de '{coluna}'")
    plt.xlabel(coluna)
    plt.ylabel("Quantidade")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

print("\nFrequência relativa:")
for coluna in colunas_categoricas:
    frequencia_relativa = (
        df[coluna]
        .value_counts(normalize=True, dropna=False)
        .round(2)
    )
    
    print(f"\nVariável '{coluna}' (%):")
    print(frequencia_relativa.round(2))

    plt.figure(figsize=(10, 5))
    frequencia_relativa.plot(kind="bar")

    plt.title(f"Frequência relativa de '{coluna}'")
    plt.xlabel(coluna)
    plt.ylabel("Percentual (%)")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()


print_formatado("3. Categoria mais frequente:")
for coluna in colunas_categoricas:
    categoria_mais_frequente = df[coluna].mode(dropna=False)[0]
    quantidade = df[coluna].value_counts(dropna=False).iloc[0]

    percentual = (
        df[coluna]
        .value_counts(normalize=True, dropna=False)
        .iloc[0] * 100
    )

    print(f"\nCategoria mais frequente da variável '{coluna}':")
    print(f"Categoria: {categoria_mais_frequente}")
    print(f"Quantidade: {quantidade}")
    print(f"Percentual: {percentual:.2f}%")
# Out:
# 1. Quantidade de categorias:
#
# Quantidade de categorias únicas por variável:
# Customer Gender       3
# Product Purchased    42
# Ticket Type           5
# Ticket Subject       16
# Ticket Status         3
# Ticket Priority       4
# Ticket Channel        4
# dtype: int64
#
#
# ====================================================================================================
# 2. Frequência absoluta e relativa:
# ====================================================================================================
#
# Frequência absoluta:
#
# Variável 'Customer Gender':
# Customer Gender
# Male      2896
# Female    2887
# Other     2686
# Name: count, dtype: int64
# Variável 'Product Purchased':
# Product Purchased
# Canon EOS                         240
# GoPro Hero                        228
# Nest Thermostat                   225
# Amazon Echo                       221
# Philips Hue Lights                221
# LG Smart TV                       219
# Sony Xperia                       217
# Roomba Robot Vacuum               216
# Apple AirPods                     213
# LG OLED                           213
# iPhone                            212
# Sony 4K HDR TV                    210
# Garmin Forerunner                 208
# LG Washing Machine                208
# Canon DSLR Camera                 206
# Nikon D                           204
# Google Pixel                      203
# Nintendo Switch Pro Controller    203
# Fitbit Charge                     202
# Sony PlayStation                  202
# HP Pavilion                       200
# Microsoft Office                  200
# Amazon Kindle                     198
# Dyson Vacuum Cleaner              198
# Google Nest                       198
# Bose SoundLink Speaker            197
# Autodesk AutoCAD                  196
# Microsoft Xbox Controller         196
# Samsung Galaxy                    194
# PlayStation                       192
# Fitbit Versa Smartwatch           191
# Bose QuietComfort                 190
# Microsoft Surface                 190
# Samsung Soundbar                  188
# Asus ROG                          187
# Xbox                              187
# MacBook Pro                       186
# Dell XPS                          185
# GoPro Action Camera               183
# Lenovo ThinkPad                   183
# Adobe Photoshop                   181
# Nintendo Switch                   178
# Name: count, dtype: int64
# Variável 'Ticket Type':
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64
# Variável 'Ticket Subject':
# Ticket Subject
# Refund request              576
# Software bug                574
# Product compatibility       567
# Delivery problem            561
# Hardware issue              547
# Battery life                542
# Network problem             539
# Installation support        530
# Product setup               529
# Payment issue               526
# Product recommendation      517
# Account access              509
# Peripheral compatibility    496
# Data loss                   491
# Cancellation request        487
# Display issue               478
# Name: count, dtype: int64
# Variável 'Ticket Status':
# Ticket Status
# Pending Customer Response    2881
# Open                         2819
# Closed                       2769
# Name: count, dtype: int64
# Variável 'Ticket Priority':
# Ticket Priority
# Medium      2192
# Critical    2129
# High        2085
# Low         2063
# Name: count, dtype: int64
# Variável 'Ticket Channel':
# Ticket Channel
# Email           2143
# Phone           2132
# Social media    2121
# Chat            2073
# Name: count, dtype: int64
# Frequência relativa:
#
# Variável 'Customer Gender' (%):
# Customer Gender
# Male      0.34
# Female    0.34
# Other     0.32
# Name: proportion, dtype: float64
# Variável 'Product Purchased' (%):
# Product Purchased
# Canon EOS                         0.03
# GoPro Hero                        0.03
# Nest Thermostat                   0.03
# Amazon Echo                       0.03
# Philips Hue Lights                0.03
# LG Smart TV                       0.03
# Sony Xperia                       0.03
# Roomba Robot Vacuum               0.03
# Apple AirPods                     0.03
# LG OLED                           0.03
# iPhone                            0.03
# Sony 4K HDR TV                    0.02
# Garmin Forerunner                 0.02
# LG Washing Machine                0.02
# Canon DSLR Camera                 0.02
# Nikon D                           0.02
# Google Pixel                      0.02
# Nintendo Switch Pro Controller    0.02
# Fitbit Charge                     0.02
# Sony PlayStation                  0.02
# HP Pavilion                       0.02
# Microsoft Office                  0.02
# Amazon Kindle                     0.02
# Dyson Vacuum Cleaner              0.02
# Google Nest                       0.02
# Bose SoundLink Speaker            0.02
# Autodesk AutoCAD                  0.02
# Microsoft Xbox Controller         0.02
# Samsung Galaxy                    0.02
# PlayStation                       0.02
# Fitbit Versa Smartwatch           0.02
# Bose QuietComfort                 0.02
# Microsoft Surface                 0.02
# Samsung Soundbar                  0.02
# Asus ROG                          0.02
# Xbox                              0.02
# MacBook Pro                       0.02
# Dell XPS                          0.02
# GoPro Action Camera               0.02
# Lenovo ThinkPad                   0.02
# Adobe Photoshop                   0.02
# Nintendo Switch                   0.02
# Name: proportion, dtype: float64
# Variável 'Ticket Type' (%):
# Ticket Type
# Refund request          0.21
# Technical issue         0.21
# Cancellation request    0.20
# Product inquiry         0.19
# Billing inquiry         0.19
# Name: proportion, dtype: float64
# Variável 'Ticket Subject' (%):
# Ticket Subject
# Refund request              0.07
# Software bug                0.07
# Product compatibility       0.07
# Delivery problem            0.07
# Hardware issue              0.06
# Battery life                0.06
# Network problem             0.06
# Installation support        0.06
# Product setup               0.06
# Payment issue               0.06
# Product recommendation      0.06
# Account access              0.06
# Peripheral compatibility    0.06
# Data loss                   0.06
# Cancellation request        0.06
# Display issue               0.06
# Name: proportion, dtype: float64
# Variável 'Ticket Status' (%):
# Ticket Status
# Pending Customer Response    0.34
# Open                         0.33
# Closed                       0.33
# Name: proportion, dtype: float64
# Variável 'Ticket Priority' (%):
# Ticket Priority
# Medium      0.26
# Critical    0.25
# High        0.25
# Low         0.24
# Name: proportion, dtype: float64
# Variável 'Ticket Channel' (%):
# Ticket Channel
# Email           0.25
# Phone           0.25
# Social media    0.25
# Chat            0.24
# Name: proportion, dtype: float64
# ====================================================================================================
# 3. Categoria mais frequente:
# ====================================================================================================
#
# Categoria mais frequente da variável 'Customer Gender':
# Categoria: Male
# Quantidade: 2896
# Percentual: 34.20%
#
# Categoria mais frequente da variável 'Product Purchased':
# Categoria: Canon EOS
# Quantidade: 240
# Percentual: 2.83%
#
# Categoria mais frequente da variável 'Ticket Type':
# Categoria: Refund request
# Quantidade: 1752
# Percentual: 20.69%
#
# Categoria mais frequente da variável 'Ticket Subject':
# Categoria: Refund request
# Quantidade: 576
# Percentual: 6.80%
#
# Categoria mais frequente da variável 'Ticket Status':
# Categoria: Pending Customer Response
# Quantidade: 2881
# Percentual: 34.02%
#
# Categoria mais frequente da variável 'Ticket Priority':
# Categoria: Medium
# Quantidade: 2192
# Percentual: 25.88%
#
# Categoria mais frequente da variável 'Ticket Channel':
# Categoria: Email
# Quantidade: 2143
# Percentual: 25.30%

# %% [markdown]
# ### Observações Análise Univariada

# %% [markdown]
# #### Variáveis numéricas
#
# * A média de `Customer Age` é 44,03 e a mediana é 44, praticamente iguais.
#     * A distribuição é quase uniforme entre 18 e 70 anos: cada faixa de idade concentra um percentual parecido de clientes, então o histograma não tem formato de sino.
#     * Os quartis ficam em 31 e 57, com desvio-padrão de 15,3, confirmando valores bem espalhados por toda a faixa.
# * A média de `Customer Satisfaction Rating` é 2,99 e a mediana é 3, bem no centro da escala.
#     * É uma variável numérica discreta: só existem as notas de 1 a 5, por isso a distribuição é visualizada com barras discretas no lugar de histograma contínuo.
#     * Cada nota aparece em cerca de 20% dos tickets avaliados, sem tendência de satisfação nem de insatisfação.
#     * As estatísticas consideram apenas os 2.769 tickets `Closed`, que são os únicos com nota, conforme definido na limpeza.
# * `Ticket ID` ficou fora da análise por ser apenas identificador.
#
# #### Variáveis categóricas
#
# * Nenhuma variável é desequilibrada. A razão entre a categoria mais frequente e a menos frequente vai de 1,03 em `Ticket Channel` até 1,35 em `Product Purchased`, abaixo do nível de desequilíbrio definido de 2.
# * As categorias mais frequentes vencem por pouca margem: `Male` com 34,2%, `Refund request` com 20,7% dos tipos de ticket, `Pending Customer Response` com 34,0%, `Medium` com 25,9% e `Email` com 25,3%.
# * `Product Purchased` tem 42 categorias e `Ticket Subject` tem 16. As demais variáveis têm entre 3 e 5.
#
# #### Outras observações:
#
# * Como nenhuma categoria é rara, não é necessário agrupar categorias minoritárias nas próximas análises.

# %% [markdown]
# ---
